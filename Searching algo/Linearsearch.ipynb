# %% [markdown]
# Linear Search is a simple searching algorithm in which each element of a list or array is checked one by one, starting from the first element, until the target element is found or the end of the list is reached.

# %%
def ls(arr,target):
    s = len(arr)
    for i in range(s):
        if nums[i] == target:
            return i
    return -1

nums = [1,2,3,4,5,6,7]
target = int(input())

result = ls(nums,target)

print(result)
# Out:
# 2
