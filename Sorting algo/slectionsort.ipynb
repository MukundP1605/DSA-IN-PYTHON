# %% [markdown]
# ### selection sort

# %%
arr = [1,4,6,3,6,8,4]
n = len(arr)

end = n - 1
for i in range(end):
    m = i
    start = i + 1
    
    for j in range(start, n):
        
        if arr[j] < arr[m]:         
            arr[j],arr[m] = arr[m] , arr[j]
print(arr)
# Out:
# [1, 3, 4, 4, 6, 6, 8]
